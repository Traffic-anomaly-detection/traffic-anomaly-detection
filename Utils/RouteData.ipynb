# %% [markdown]
# <a href="https://colab.research.google.com/github/swaggytt/traffic-anomaly-detection/blob/master/RouteData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_roaddb = pd.read_csv("/content/drive/MyDrive/ Project/routes_data/roaddb.csv")
df_throute = pd.read_csv("/content/drive/MyDrive/ Project/routes_data/thailand_routes.csv")

# %%
df_roaddb
# Out:
#           rid    rd      km ptype  ...         lon    latx     lonx  angle
# 0           1  3003   0.000  100m  ...  100.066108  14.493  100.066    180
# 1           1  3003   0.100  100m  ...  100.066290  14.494  100.066    180
# 2           1  3003   0.200  100m  ...  100.066476  14.495  100.066    179
# 3           1  3003   0.300  100m  ...  100.066658  14.496  100.067    179
# 4           1  3003   0.400  100m  ...  100.066839  14.496  100.067    179
# ...       ...   ...     ...   ...  ...         ...     ...      ...    ...
# 1093650  6510  2038  19.900  100m  ...  102.297042  16.677  102.297    177
# 1093651  6510  2038  20.000   1km  ...  102.297096  16.678  102.297    180
# 1093652  6510  2038  20.005  bend  ...  102.297089  16.678  102.297    118
# 1093653  6510  2038  20.055  bend  ...  102.296661  16.678  102.297    114
# 1093654  6510  2038  20.050  100m  ...  102.296661  16.678  102.297    180
#
# [1093655 rows x 9 columns]

# %%
df_roaddb[df_roaddb["rd"]==7]
# Out:
#          rid  rd      km ptype        lat         lon    latx     lonx  angle
# 924110  5662   7   0.000  100m  13.730594  100.760581  13.731  100.761    180
# 924111  5662   7   0.100  100m  13.731494  100.760582  13.731  100.761    180
# 924112  5662   7   0.200  100m  13.732393  100.760584  13.732  100.761    179
# 924113  5662   7   0.300  100m  13.733292  100.760585  13.733  100.761    162
# 924114  5662   7   0.400  100m  13.734112  100.760864  13.734  100.761    180
# ...      ...  ..     ...   ...        ...         ...     ...      ...    ...
# 925891  5672   7  46.900  100m  12.944657  100.907329  12.945  100.907    180
# 925892  5672   7  47.000   1km  12.944803  100.906418  12.945  100.906    180
# 925893  5672   7  47.100  100m  12.944949  100.905508  12.945  100.906    180
# 925894  5672   7  47.168  bend  12.945047  100.904891  12.945  100.905     99
# 925895  5672   7  47.170  100m  12.945047  100.904891  12.945  100.905    180
#
# [1451 rows x 9 columns]

# %%
df_throute
# Out:
#       rd   km        lat         lon
# 0      2  343  16.493426  102.832585
# 1      2  344  16.502454  102.832577
# 2      2  345  16.511481  102.832553
# 3      2  345  16.511481  102.832553
# 4      2  346  16.520498  102.832247
# ...   ..  ...        ...         ...
# 3562   4   11  13.721160  100.458640
# 3563   4   10  13.725500  100.466660
# 3564   4    9  13.729370  100.474820
# 3565   4    8  13.727790  100.484000
# 3566   4    7  13.726290  100.493230
#
# [3567 rows x 4 columns]

# %%
df_throute.value_counts(["rd"])
# Out:
# rd
# 4     1365
# 1     1099
# 2      607
# 3      496
# dtype: int64

# %%
df_throute_1 = df_throute[df_throute["rd"]==1]
df_throute_2 = df_throute[df_throute["rd"]==2]
df_throute_3 = df_throute[df_throute["rd"]==3]

# %%
df_throute_1.sort_values(["km"])
# Out:
#       rd   km        lat         lon
# 3537   1   19  13.879176  100.598832
# 3487   1   25  13.926152  100.626455
# 3488   1   26  13.935066  100.625095
# 3489   1   27  13.943972  100.623483
# 267    1   28  13.952894  100.621930
# ...   ..  ...        ...         ...
# 3129   1  990  20.402477   99.884987
# 3130   1  991  20.411322   99.885934
# 3131   1  992  20.419902   99.883795
# 3132   1  993  20.428256   99.884444
# 3133   1  994  20.436869   99.883649
#
# [1099 rows x 4 columns]

# %%
fig = px.scatter_mapbox(df_throute_1, lat="lat", lon="lon")
fig.update_layout(mapbox_style="open-street-map") 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7d78225e-0a70-4710-b1fe-05b3caba9d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d78225e-0a70-4710-b1fe-05b3caba9d97")) {
#                     Plotly.newPlot(
#                         '7d78225e-0a70-4710-b1fe-05b3caba9d97',
# ...
